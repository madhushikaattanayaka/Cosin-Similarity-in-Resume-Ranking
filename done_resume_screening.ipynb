# %%
import pandas as pd
import nltk
import re #regex mdule ekak
from nltk.corpus import wordnet
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords as stp
from nltk.tag import pos_tag
from sklearn.feature_extraction.text import CountVectorizer
#nltk.download()

# %% [markdown]
# # Data set Reading

# %%
df = pd.read_csv('Resume Ranking Data Set.csv')
df_cp = df.copy()

# %%
df.head(20)
# Out:
#                               accomplishments_segment             degree  \
# 0                                                 NaN  MS , B.TECH , PhD
# 1                                                 NaN  B.E , MS , M.TECH
# 2   Successfully cleared and completed the course ...   MS , B.TECH , BS
# 3                                                 NaN      B.E , MS , BS
# 4                                                 NaN   MS , B.TECH , BS
# 5                                                 NaN             B.TECH
# 6                                                 NaN      B.E , MS , BS
# 7                                                 NaN     BTECH , B.TECH
# 8                                                 NaN        B.TECH , BS
# 9                                                 NaN   MS , B.TECH , BS
# 10                                                NaN             B.TECH
# 11                                                NaN   MS , B.TECH , BS
# 12                                                NaN                NaN
# 13                                                NaN        MS , B.TECH
# 14                                                NaN        MS , B.TECH
# 15                                                NaN                 MS
# 16                                                NaN        MS , B.TECH
# 17  OpenMined, Virtual\nJul 2020 - Sep 2020\n Inte...           B.E , MS
# 18                                                NaN   MS , B.TECH , BS
# 19                                                NaN           B.S , MS
#
#                                     education_segment  \
# 0                                                 NaN
# 1   M.Tech. Data Science\nJSS Science And Technolo...
# 2   Degree\nInstitute\nBoard/University\nYear\nPer...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                           emails  \
# 0     sutarvinayak2063@gmail.com
# 1              pooj.vs@gmail.com
# 2   khandelwal.ashwin5@gmail.com
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                           NaN
#
#                                            job_titles  \
# 0                      full stack developer , student
# 1                                   software engineer
# 2                                                 NaN
# 3   work from home , support analyst , software an...
# 4                         work from home , classifier
# 5                                      work from home
# 6         work from home , secretary , data scientist
# 7                            work from home , partner
# 8                    project manager , work from home
# 9                     pizza delivery , work from home
# 10                                     work from home
# 11             work from home , team member , student
# 12                           work from home , partner
# 13  work from home , representative , secretary , ...
# 14                         work from home , full time
# 15                                     work from home
# 16                  work from home , committee member
# 17  research engineer , work from home , full time...
# 18  work from home , software engineer , java deve...
# 19                                     work from home
#
#                                                 links  \
# 0   https://github.com/ramsuthar305/SIH2019 , http...
# 1                                             pooj.vs
# 2   https://www.linkedin.com/in/ashwin-khandelwal-...
# 3                                                 NaN
# 4   https://github.com/ajay1013/Titanic-ML-from-Di...
# 5                                                 NaN
# 6                                                 NaN
# 7   in.programy.noq , https://github.com/kumaranki...
# 8   https://play.google.com/store/apps/details , h...
# 9   https://github.com/ayush-09/Face_Mask_Detector...
# 10                                                NaN
# 11  https://github.com/AadityaSingh360/Photo-Blog ...
# 12                                                NaN
# 13                                                NaN
# 14  https://github.com/aashish350/Bank/commit/66c9...
# 15                                                NaN
# 16                                                NaN
# 17  https://github.com/abbas5253/Compact_NN , http...
# 18                                                NaN
# 19                                                NaN
#
#                                          misc_segment                  name  \
# 0                                                 NaN          Prasad Nagar
# 1   06/2017 – 07/2019\n07/2018 – 07/2019\nmailto:p...     Software Engineer
# 2                                                 NaN     Ashwin Khandelwal
# 3                                                 NaN  Computer Engineering
# 4                                                 NaN             Python
# 5                                                 NaN    AKSHAY DESHBHRATAR
# 6                                                 NaN      kaashiv infotech
# 7                                                 NaN           IIT Roorkee
# 8                                                 NaN           West Bengal
# 9                                                 NaN      Apache Cassandra
# 10                                                NaN        Android Studio
# 11                                                NaN         Aaditya Singh
# 12                                                NaN          Aakash Singh
# 13                                                NaN           2months i.e
# 14                                                NaN         Aashish Kumar
# 15                                                NaN          Aastha Patel
# 16                                                NaN          Data Science
# 17                                                NaN          Abbas Ismail
# 18                                                NaN           Abdeali Tin
# 19                                                NaN           Abdul Rahim
#
#                                    objectives_segment  \
# 0                                                 NaN
# 1                                                 NaN
# 2   I seek challenging environment to work in, tha...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                        phone  ...  \
# 0                              +919309161108  ...
# 1                                 7411786822  ...
# 2                                 9462710290  ...
# 3                               919930485336  ...
# 4                               918010295832  ...
# 5                               918888238622  ...
# 6                               919884679445  ...
# 7                               917302202034  ...
# 8                               918405978077  ...
# 9                               917060209421  ...
# 10                              918171637443  ...
# 11                              918318524571  ...
# 12                              916265133988  ...
# 13                              918887924287  ...
# 14  4681098857 , 917388118731 , 242733285681  ...
# 15                              917778013442  ...
# 16                              918169290155  ...
# 17                              917869469532  ...
# 18                              917415499986  ...
# 19                 8904548813 , 918904548813  ...
#
#                                                  text  \
# 0   VINAYAK \nSUTAR \nLinkedIn  \n+91 9309161108  ...
# 1   POOJA V S\nSoftware Engineer\nRich exposure to...
# 2   Ashwin Khandelwal          \n Email id – khand...
# 3   Assessment\nQ1. Why should you be hired for th...
# 4   Assessment\nQ1. Why should you be hired for th...
# 5   Assessment\nQ1. Why should you be hired for th...
# 6   Assessment\nQ1. Why should you be hired for th...
# 7   Assessment\nQ1. Why should you be hired for th...
# 8   Assessment\nQ1. Why should you be hired for th...
# 9   Assessment\nQ1. Why should you be hired for th...
# 10  Assessment\nQ1. Why should you be hired for th...
# 11  Assessment\nQ1. Why should you be hired for th...
# 12  Assessment\nQ1. Why should you be hired for th...
# 13  Assessment\nQ1. Why should you be hired for th...
# 14  Assessment\nQ1. Why should you be hired for th...
# 15  Assessment\nQ1. Why should you be hired for th...
# 16  Assessment\nQ1. Why should you be hired for th...
# 17  Assessment\nQ1. Why should you be hired for th...
# 18  Assessment\nQ1. Why should you be hired for th...
# 19  Assessment\nQ1. Why should you be hired for th...
#
#                                          university_0  \
# 0                   national, mainpuri, uttar pradesh
# 1                       government, kandhamal, odisha
# 2   narsee monjee institute of management studies,...
# 3                            master, medak, telangana
# 4   greater noida institute of technology, gautam ...
# 5            government polytechnic, kachchh, gujarat
# 6   jeppiaar engineering college, kancheepuram, ta...
# 7   indian institute of technology, saharanpur, ut...
# 8         nshm knowledge campus, kolkata, west bengal
# 9                                                 NaN
# 10  institute of technology, gorakhpur, uttar pradesh
# 11  institute of technology, gorakhpur, uttar pradesh
# 12                           master, medak, telangana
# 13  college of engineering, visakhapatnam, andhra ...
# 14              engineering college, ajmer, rajasthan
# 15                                                NaN
# 16                                                NaN
# 17  birla institute of technology, allahabad, utta...
# 18                sri aurobindo college, south, delhi
# 19                                                NaN
#
#                                          university_1  \
# 0                 college of arts, sundargarh, odisha
# 1   vidya vardhaka college of engineering, mysore,...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                            master, medak, telangana
# 8                                                 NaN
# 9                                                 NaN
# 10                  national, mainpuri, uttar pradesh
# 11                  national, mainpuri, uttar pradesh
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                          university_2 university_3  \
# 0            school of engineering, ernakulam, kerala          NaN
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7   institute of technology roorkee, hardwar, uttr...          NaN
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 10                                                NaN          NaN
# 11                                                NaN          NaN
# 12                                                NaN          NaN
# 13                                                NaN          NaN
# 14                                                NaN          NaN
# 15                                                NaN          NaN
# 16                                                NaN          NaN
# 17                                                NaN          NaN
# 18                                                NaN          NaN
# 19                                                NaN          NaN
#
#    university_4 university_5  \
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN
# 6           NaN          NaN
# 7           NaN          NaN
# 8           NaN          NaN
# 9           NaN          NaN
# 10          NaN          NaN
# 11          NaN          NaN
# 12          NaN          NaN
# 13          NaN          NaN
# 14          NaN          NaN
# 15          NaN          NaN
# 16          NaN          NaN
# 17          NaN          NaN
# 18          NaN          NaN
# 19          NaN          NaN
#
#                                                   url work_experience  \
# 0   https://training-resumes.s3.ap-south-1.amazona...             NaN
# 1   https://training-resumes.s3.ap-south-1.amazona...             NaN
# 2   https://training-resumes.s3.ap-south-1.amazona...             NaN
# 3   https://training-resumes.s3.ap-south-1.amazona...             1.0
# 4   https://training-resumes.s3.ap-south-1.amazona...             NaN
# 5   https://training-resumes.s3.ap-south-1.amazona...             5.0
# 6   https://training-resumes.s3.ap-south-1.amazona...             NaN
# 7   https://training-resumes.s3.ap-south-1.amazona...             NaN
# 8   https://training-resumes.s3.ap-south-1.amazona...             NaN
# 9   https://training-resumes.s3.ap-south-1.amazona...             NaN
# 10  https://training-resumes.s3.ap-south-1.amazona...             NaN
# 11  https://training-resumes.s3.ap-south-1.amazona...             NaN
# 12  https://training-resumes.s3.ap-south-1.amazona...             NaN
# 13  https://training-resumes.s3.ap-south-1.amazona...             NaN
# 14  https://training-resumes.s3.ap-south-1.amazona...             NaN
# 15  https://training-resumes.s3.ap-south-1.amazona...             NaN
# 16  https://training-resumes.s3.ap-south-1.amazona...             NaN
# 17  https://training-resumes.s3.ap-south-1.amazona...             4.0
# 18  https://training-resumes.s3.ap-south-1.amazona...             4.0
# 19  https://training-resumes.s3.ap-south-1.amazona...             NaN
#
#                                          work_segment
# 0                                                 NaN
# 1   Merchandising System' using PL/SQL.\nmaintain ...
# 2   Organization / Institute\nDescription\nBharat ...
# 3                                                 NaN
# 4                                                 NaN
# 5   TRAININGS\nThuse Electronics Private Limited,B...
# 6          POSIT IONS OF\nRESPONSIBILITY\nTRAININGS\n
# 7                                                 NaN
# 8                                                 NaN
# 9                                         TRAININGS\n
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  POSIT IONS OF\nRESPONSIBILITY\nTRAININGS\nAbba...
# 18                                                NaN
# 19                                                NaN
#
# [20 rows x 23 columns]

# %% [markdown]
# # Null Values

# %%
df.isnull().sum()#ek eka columns wala numm value count ek denwaaa
# Out:
# accomplishments_segment    1507
# degree                       38
# education_segment          1116
# emails                     1509
# job_titles                   27
# links                       354
# misc_segment               1551
# name                          1
# objectives_segment         1159
# phone                       219
# projects_segment            893
# skills                        0
# skills_segment             1105
# text                          0
# university_0               1007
# university_1               1305
# university_2               1480
# university_3               1545
# university_4               1568
# university_5               1571
# url                           0
# work_experience             854
# work_segment                893
# dtype: int64

# %% [markdown]
# # Dropping the features which doesn't required

# %%
df.drop(['accomplishments_segment','education_segment','emails','misc_segment','name','objectives_segment','phone','projects_segment','skills_segment','text',
         'university_0','university_1','university_2','university_3','university_4','university_5','url','work_segment'],axis=1,inplace=True)
df.shape
# Out:
# (1573, 5)

# %% [markdown]
# # Total null values of features after dropping the features

# %%
print('After removing the columns from dataset total null values')
df.isnull().sum()
# Out:
# After removing the columns from dataset total null values
# degree              38
# job_titles          27
# links              354
# skills               0
# work_experience    854
# dtype: int64

# %% [markdown]
# # Handling Null values of features

# %%
df['degree'].fillna(df.degree.mode()[0],inplace=True)
df['links'].fillna('Missing',inplace=True)
df['work_experience'].fillna(0,inplace=True)
df['job_titles'].fillna('No Job',inplace=True)
df.head()
# Out:
#               degree                                         job_titles  \
# 0  MS , B.TECH , PhD                     full stack developer , student
# 1  B.E , MS , M.TECH                                  software engineer
# 2   MS , B.TECH , BS                                             No Job
# 3      B.E , MS , BS  work from home , support analyst , software an...
# 4   MS , B.TECH , BS                        work from home , classifier
#
#                                                links  \
# 0  https://github.com/ramsuthar305/SIH2019 , http...
# 1                                            pooj.vs
# 2  https://www.linkedin.com/in/ashwin-khandelwal-...
# 3                                            Missing
# 4  https://github.com/ajay1013/Titanic-ML-from-Di...
#
#                                               skills  work_experience
# 0  algorithms , interview , visualisation , robot...              0.0
# 1  core java , algorithms , sql tools , deep lear...              0.0
# 2  digital signal processing , algorithms , capac...              0.0
# 3  big data analytics , award , training , comput...              1.0
# 4  functionality , algorithms , spark , data visu...              0.0

# %%
all_degrees = ''
for i in df.degree:
  if len(all_degrees) == 0:
    all_degrees = i
  else:
    all_degrees = all_degrees + ' , ' + i

all_degrees = all_degrees.split(',')
all_degrees = [re.sub("[\s.]","",i).upper() for i in all_degrees]
unique_degrees = set(all_degrees)
unique_degrees
# Out:
# {'BE', 'BS', 'BSC', 'BTECH', 'ME', 'MS', 'MSC', 'MTECH', 'PHD'}

# %%
df['bachelor_degrees'] = 'No Degree'
df['master_degrees'] = 'No Degree'
df['docterte_degrees'] = 'No Degree'
df['profiles'] = 'No Profile'

# %%
df.head()
# Out:
#               degree                                         job_titles  \
# 0  MS , B.TECH , PhD                     full stack developer , student
# 1  B.E , MS , M.TECH                                  software engineer
# 2   MS , B.TECH , BS                                             No Job
# 3      B.E , MS , BS  work from home , support analyst , software an...
# 4   MS , B.TECH , BS                        work from home , classifier
#
#                                                links  \
# 0  https://github.com/ramsuthar305/SIH2019 , http...
# 1                                            pooj.vs
# 2  https://www.linkedin.com/in/ashwin-khandelwal-...
# 3                                            Missing
# 4  https://github.com/ajay1013/Titanic-ML-from-Di...
#
#                                               skills  work_experience  \
# 0  algorithms , interview , visualisation , robot...              0.0
# 1  core java , algorithms , sql tools , deep lear...              0.0
# 2  digital signal processing , algorithms , capac...              0.0
# 3  big data analytics , award , training , comput...              1.0
# 4  functionality , algorithms , spark , data visu...              0.0
#
#   bachelor_degrees master_degrees docterte_degrees    profiles
# 0        No Degree      No Degree        No Degree  No Profile
# 1        No Degree      No Degree        No Degree  No Profile
# 2        No Degree      No Degree        No Degree  No Profile
# 3        No Degree      No Degree        No Degree  No Profile
# 4        No Degree      No Degree        No Degree  No Profile

# %%
ind = 0
for i in df.degree:  
  lst = re.sub("[\s.]","",i).upper( )
  # print(lst)
  for j in lst.split(','):
    if j in ['BE', 'BS', 'BSC', 'BTECH']:
      if df.loc[ind,'bachelor_degrees'] == 'No Degree':
        df.loc[ind,'bachelor_degrees'] = j
      else:
        df.loc[ind,'bachelor_degrees'] = df.loc[ind,'bachelor_degrees'] + ' , '+ j
    elif j in ['ME', 'MS', 'MSC', 'MTECH']:      
      if df.loc[ind,'master_degrees'] == 'No Degree':
        df.loc[ind,'master_degrees'] = j
      else:
        df.loc[ind,'master_degrees'] = df.loc[ind,'master_degrees'] + ' , '+ j
    elif j == 'PHD':      
      if df.loc[ind,'docterte_degrees'] == 'No Degree':
        df.loc[ind,'docterte_degrees'] = j
      else:
        df.loc[ind,'docterte_degrees'] = df.loc[ind,'docterte_degrees'] + ' , '+ j
  ind +=1

# %%
df
# Out:
#                           degree  \
# 0              MS , B.TECH , PhD
# 1              B.E , MS , M.TECH
# 2               MS , B.TECH , BS
# 3                  B.E , MS , BS
# 4               MS , B.TECH , BS
# ...                          ...
# 1568           B.E , MS , M.TECH
# 1569                     MS , BS
# 1570  B.S , M.Sc , M.S , BS , MS
# 1571                          MS
# 1572                          BS
#
#                                              job_titles  \
# 0                        full stack developer , student
# 1                                     software engineer
# 2                                                No Job
# 3     work from home , support analyst , software an...
# 4                           work from home , classifier
# ...                                                 ...
# 1568  branch manager , embedded software developer ,...
# 1569      devops , senior android developer , team lead
# 1570  devops engineer , traffic manager , release ma...
# 1571                                         classifier
# 1572                                             No Job
#
#                                                   links  \
# 0     https://github.com/ramsuthar305/SIH2019 , http...
# 1                                               pooj.vs
# 2     https://www.linkedin.com/in/ashwin-khandelwal-...
# 3                                               Missing
# 4     https://github.com/ajay1013/Titanic-ML-from-Di...
# ...                                                 ...
# 1568  https://www.linkedin.com/in , https://grv20.gi...
# 1569  com.gokada , https://play.google.com/store/app...
# 1570  https://freesearch.naukri.com/preview/printResume
# 1571                                            Missing
# 1572                 https://github.com/YashshreeShinde
#
#                                                  skills  work_experience  \
# 0     algorithms , interview , visualisation , robot...              0.0
# 1     core java , algorithms , sql tools , deep lear...              0.0
# 2     digital signal processing , algorithms , capac...              0.0
# 3     big data analytics , award , training , comput...              1.0
# 4     functionality , algorithms , spark , data visu...              0.0
# ...                                                 ...              ...
# 1568  digital communication , api , atom , robot , c...              2.0
# 1569  reporting , functionality , socket.io , mockit...              2.0
# 1570  version control , renewals , nfs , telugu , vi...             12.0
# 1571  natural language , matplotlib , boost , custom...              0.0
# 1572  employability , python , github , javascript ,...              0.0
#
#      bachelor_degrees master_degrees docterte_degrees    profiles
# 0               BTECH             MS              PHD  No Profile
# 1                  BE     MS , MTECH        No Degree  No Profile
# 2          BTECH , BS             MS        No Degree  No Profile
# 3             BE , BS             MS        No Degree  No Profile
# 4          BTECH , BS             MS        No Degree  No Profile
# ...               ...            ...              ...         ...
# 1568               BE     MS , MTECH        No Degree  No Profile
# 1569               BS             MS        No Degree  No Profile
# 1570          BS , BS  MSC , MS , MS        No Degree  No Profile
# 1571        No Degree             MS        No Degree  No Profile
# 1572               BS      No Degree        No Degree  No Profile
#
# [1573 rows x 9 columns]

# %%
ind = 0
for i in df.links:
  lst = re.sub("[\s]","",i)
  # print(lst)
  for j in lst.split(','):
    if j.find('github') != -1:          
      df.loc[ind,'profiles'] = 'Github'
    elif j.find('linkedin') != -1:
      if df.loc[ind,'profiles'] == 'No Profile':
        df.loc[ind,'profiles'] = 'Linkedin'
      else:
        df.loc[ind,'profiles'] = df.loc[ind,'profiles'] + ' , ' + 'Linkedin'
  ind +=1

# %%
df
# Out:
#                           degree  \
# 0              MS , B.TECH , PhD
# 1              B.E , MS , M.TECH
# 2               MS , B.TECH , BS
# 3                  B.E , MS , BS
# 4               MS , B.TECH , BS
# ...                          ...
# 1568           B.E , MS , M.TECH
# 1569                     MS , BS
# 1570  B.S , M.Sc , M.S , BS , MS
# 1571                          MS
# 1572                          BS
#
#                                              job_titles  \
# 0                        full stack developer , student
# 1                                     software engineer
# 2                                                No Job
# 3     work from home , support analyst , software an...
# 4                           work from home , classifier
# ...                                                 ...
# 1568  branch manager , embedded software developer ,...
# 1569      devops , senior android developer , team lead
# 1570  devops engineer , traffic manager , release ma...
# 1571                                         classifier
# 1572                                             No Job
#
#                                                   links  \
# 0     https://github.com/ramsuthar305/SIH2019 , http...
# 1                                               pooj.vs
# 2     https://www.linkedin.com/in/ashwin-khandelwal-...
# 3                                               Missing
# 4     https://github.com/ajay1013/Titanic-ML-from-Di...
# ...                                                 ...
# 1568  https://www.linkedin.com/in , https://grv20.gi...
# 1569  com.gokada , https://play.google.com/store/app...
# 1570  https://freesearch.naukri.com/preview/printResume
# 1571                                            Missing
# 1572                 https://github.com/YashshreeShinde
#
#                                                  skills  work_experience  \
# 0     algorithms , interview , visualisation , robot...              0.0
# 1     core java , algorithms , sql tools , deep lear...              0.0
# 2     digital signal processing , algorithms , capac...              0.0
# 3     big data analytics , award , training , comput...              1.0
# 4     functionality , algorithms , spark , data visu...              0.0
# ...                                                 ...              ...
# 1568  digital communication , api , atom , robot , c...              2.0
# 1569  reporting , functionality , socket.io , mockit...              2.0
# 1570  version control , renewals , nfs , telugu , vi...             12.0
# 1571  natural language , matplotlib , boost , custom...              0.0
# 1572  employability , python , github , javascript ,...              0.0
#
#      bachelor_degrees master_degrees docterte_degrees           profiles
# 0               BTECH             MS              PHD             Github
# 1                  BE     MS , MTECH        No Degree         No Profile
# 2          BTECH , BS             MS        No Degree           Linkedin
# 3             BE , BS             MS        No Degree         No Profile
# 4          BTECH , BS             MS        No Degree             Github
# ...               ...            ...              ...                ...
# 1568               BE     MS , MTECH        No Degree  Github , Linkedin
# 1569               BS             MS        No Degree         No Profile
# 1570          BS , BS  MSC , MS , MS        No Degree         No Profile
# 1571        No Degree             MS        No Degree         No Profile
# 1572               BS      No Degree        No Degree             Github
#
# [1573 rows x 9 columns]

# %%
# list(df['work_experience'].unique())
df.work_experience.value_counts()
# Out:
#  0.0       854
#  4.0       151
#  2.0        91
#  1.0        87
#  3.0        81
#  5.0        73
#  6.0        52
#  8.0        34
#  7.0        32
#  9.0        23
#  14.0       14
#  11.0       12
#  10.0       12
#  12.0       11
#  13.0        6
#  18.0        5
#  15.0        4
#  17.0        4
#  21.0        4
#  22.0        2
#  2005.0      2
#  2004.0      2
#  16.0        2
#  2003.0      2
#  2006.0      2
#  20.0        2
#  2002.0      1
#  2010.0      1
#  2001.0      1
#  2012.0      1
# -3.0         1
#  1999.0      1
#  2013.0      1
#  2008.0      1
#  19.0        1
# Name: work_experience, dtype: int64

# %%
ind = 0
for i in df.work_experience:
  if i < 0:
    df.loc[ind,'work_experience'] = i*-1
  elif i > 40:
    df.loc[ind,'work_experience'] = 0
  ind +=1
df['work_experience'] = df['work_experience'].astype(int)

# %%
df
# Out:
#                                              job_titles  \
# 0                        full stack developer , student
# 1                                     software engineer
# 2                                                No Job
# 3     work from home , support analyst , software an...
# 4                           work from home , classifier
# ...                                                 ...
# 1568  branch manager , embedded software developer ,...
# 1569      devops , senior android developer , team lead
# 1570  devops engineer , traffic manager , release ma...
# 1571                                         classifier
# 1572                                             No Job
#
#                                                  skills  work_experience  \
# 0     algorithms , interview , visualisation , robot...                0
# 1     core java , algorithms , sql tools , deep lear...                0
# 2     digital signal processing , algorithms , capac...                0
# 3     big data analytics , award , training , comput...                1
# 4     functionality , algorithms , spark , data visu...                0
# ...                                                 ...              ...
# 1568  digital communication , api , atom , robot , c...                2
# 1569  reporting , functionality , socket.io , mockit...                2
# 1570  version control , renewals , nfs , telugu , vi...               12
# 1571  natural language , matplotlib , boost , custom...                0
# 1572  employability , python , github , javascript ,...                0
#
#      bachelor_degrees master_degrees docterte_degrees             profiles
# 0               BTECH             MS              PHD               Github
# 1                  BE     MS , MTECH        No Degree           No Profile
# 2          BTECH , BS             MS        No Degree  Linkedin , Linkedin
# 3             BE , BS             MS        No Degree           No Profile
# 4          BTECH , BS             MS        No Degree               Github
# ...               ...            ...              ...                  ...
# 1568               BE     MS , MTECH        No Degree    Github , Linkedin
# 1569               BS             MS        No Degree           No Profile
# 1570          BS , BS  MSC , MS , MS        No Degree           No Profile
# 1571        No Degree             MS        No Degree           No Profile
# 1572               BS      No Degree        No Degree               Github
#
# [1573 rows x 7 columns]

# %%
df.drop(['degree','links'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38020\3262523228.py in <module>
# ----> 1 df.drop(['degree','links'],axis=1,inplace=True)
#       2
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['degree', 'links'] not found in axis"

# %%
df.isnull().sum()
# Out:
# job_titles          0
# skills              0
# work_experience     0
# bachelor_degrees    0
# master_degrees      0
# docterte_degrees    0
# profiles            0
# dtype: int64

# %%
df
# Out:
#                                              job_titles  \
# 0                        full stack developer , student
# 1                                     software engineer
# 2                                                No Job
# 3     work from home , support analyst , software an...
# 4                           work from home , classifier
# ...                                                 ...
# 1568  branch manager , embedded software developer ,...
# 1569      devops , senior android developer , team lead
# 1570  devops engineer , traffic manager , release ma...
# 1571                                         classifier
# 1572                                             No Job
#
#                                                  skills  work_experience  \
# 0     algorithms , interview , visualisation , robot...                0
# 1     core java , algorithms , sql tools , deep lear...                0
# 2     digital signal processing , algorithms , capac...                0
# 3     big data analytics , award , training , comput...                1
# 4     functionality , algorithms , spark , data visu...                0
# ...                                                 ...              ...
# 1568  digital communication , api , atom , robot , c...                2
# 1569  reporting , functionality , socket.io , mockit...                2
# 1570  version control , renewals , nfs , telugu , vi...               12
# 1571  natural language , matplotlib , boost , custom...                0
# 1572  employability , python , github , javascript ,...                0
#
#      bachelor_degrees master_degrees docterte_degrees             profiles
# 0               BTECH             MS              PHD               Github
# 1                  BE     MS , MTECH        No Degree           No Profile
# 2          BTECH , BS             MS        No Degree  Linkedin , Linkedin
# 3             BE , BS             MS        No Degree           No Profile
# 4          BTECH , BS             MS        No Degree               Github
# ...               ...            ...              ...                  ...
# 1568               BE     MS , MTECH        No Degree    Github , Linkedin
# 1569               BS             MS        No Degree           No Profile
# 1570          BS , BS  MSC , MS , MS        No Degree           No Profile
# 1571        No Degree             MS        No Degree           No Profile
# 1572               BS      No Degree        No Degree               Github
#
# [1573 rows x 7 columns]

# %%
lemmatizer = WordNetLemmatizer()
analyzer = CountVectorizer().build_analyzer()

def stemmed_words(doc):
    return (lemmatizer.lemmatize(w,get_wordnet_pos(w)) for w in analyzer(doc) if w not in set(stp.words('english')))

# %%
def get_wordnet_pos(word):    
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# %%
def get_tf_idf_cosine_similarity(job_desc,all_resumes):    
    tf_idf_vect = TfidfVectorizer(analyzer=stemmed_words)
    tf_idf_desc_vector = tf_idf_vect.fit_transform([job_desc]).todense()
    tf_idf_resume_vector = tf_idf_vect.transform(all_resumes).todense()
    cosine_similarity_list = []
    for i in range(len(tf_idf_resume_vector)):
        cosine_similarity_list.append(cosine_similarity(tf_idf_desc_vector,tf_idf_resume_vector[i])[0][0])
    return cosine_similarity_list

# %% [markdown]
# # Opening the Job Description from the text file

# %%
with open('Job Description.txt','r',encoding = 'utf-8') as f:
  file_desc_lst =  [r.replace('\n', '') for r in f.readlines()]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38020\2689976439.py in <module>
# ----> 1 with open('Job Description.txt','r',encoding = 'utf-8') as f:
#       2   file_desc_lst =  [r.replace('\n', '') for r in f.readlines()]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Job Description.txt'

# %%
job_description = ''

for i in file_desc_lst:
  if len(job_description) == 0:
    job_description = str(i)
  else:
    job_description = job_description + ' ' + str(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38020\1918479882.py in <module>
#       1 job_description = ''
#       2
# ----> 3 for i in file_desc_lst:
#       4   if len(job_description) == 0:
#       5     job_description = str(i)
#
# NameError: name 'file_desc_lst' is not defined

# %%
job_description
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38020\54415180.py in <module>
# ----> 1 job_description
#
# NameError: name 'job_description' is not defined

# %% [markdown]
# # Reading all resume's from the dataset and convert into text which will appended into a list

# %%
all_resume_text = []

for i in df.iloc[:].values:
  s = ''
  for j in list(i):
    if len(s) == 0:
      s = str(j)
    else:
      s = s + ' , ' + str(j)
  all_resume_text.append(s)

# %%
all_resume_text
# Out:
# ['full stack developer , student , algorithms , interview , visualisation , robot , deep learning , sqlite , sen , cracking , information technology , hindi , maintenance , english , cpp , mongodb , linkedin , adt , iit , gaming , development work , persona , data analysis , knowledge sharing , django , research , flask , app , web , officers , 0 , BTECH , MS , PHD , No Profile',
#  'software engineer , core java , algorithms , sql tools , deep learning , media analysis , nlp , learning techniques , chess , analytics , twitter , social media , project , grasp , puzzles , application , programming languages , pl/sql , facebook , information science , rest , government , machine learning , accessibility , fusion charts , sentiment analysis , big data , kannada , oracle retail , merchandising , data science , python , javascript , eclipse , jdeveloper , web , layout , technology , information retrieval , drawing , hobbies , html , 0 , BE , MS , MTECH , No Degree , No Profile',
#  'No Job , digital signal processing , algorithms , capacitors , meshing , iit , xml , vector , keil , features , sentiment analysis , organization , challenging environment , mmic , relays , xilinx , internships , web services , pulses , project , orcad , live , numbers , microservices , synthesis , ibm , construction , matlab , rest , java , c++ , machine learning , research , wireless , campus , technology , ethical hacking , html , optimization , microsoft office , pages , adobe photoshop , design , public , instrumental , satellite , linear regression , optical fiber , instrumentation , regulations , email , high voltage , fit , surface , microwave engineering , nltk , languages , output , hibernate , rtd , database , online , bandwidth , image processing , css , circuit , cement , creativity , servlets , spring boot , embedded , devices , introduction to , pspice , paper , government , mobile computing , kaizen , vhdl , python , face recognition , cloud computing , microsoft sql server , 0 , BTECH , BS , MS , No Degree , No Profile',
#  'work from home , support analyst , software analyst , full time , associate software engineer , big data analytics , award , training , computer technology , matplotlib , algorithms , spark , nlp , case , hypothesis testing , pleasure , pandas , numpy , mumbai , edx , resume , datasets , java , machine learning , fundamentals , computer science , statistics , set theory , completion , assessment , probability , grounding , data science , python , one , computer engineering , ml , artificial intelligence , knowledge base , online , 1 , BE , BS , MS , No Degree , No Profile',
#  'work from home , classifier , functionality , algorithms , spark , data visualization , forest , classification , deep learning , mar , platforms , bash , application packaging , data analytics , statistical modeling , public , natural language processing , model building , windows , eda , commodities , venue , sql , data cleaning , records , sampling , prediction , resume , passenger , electronics , testing , machine learning , credit card fraud , tableau , completion , assessment , events , sink , tuning , data science , python , sponsorship , ml , technology , feature selection , argumentation , kt , fraud detection , online , 0 , BTECH , BS , MS , No Degree , No Profile',
#  'work from home , completion , assessment , health monitoring , resume , internships , electronics , organization , intelligence , technology , government , 5 , BTECH , No Degree , No Degree , No Profile',
#  'work from home , secretary , data scientist , internships , ease , mar , blind , volunteering , english , c programming , 3g , resume , java , computer science , research , assessment , data science , python , it , ion , artificial intelligence , technology , html , 0 , BE , BS , MS , No Degree , No Profile',
#  'work from home , partner , sunrise , api , authentication , secondary education , firebase , player , retrofit , pattern , google , kotlin , working from home , iit , resume , android , github , java , youtube , completion , assessment , app , history , search , web , technology , civil engineering , persistence , 0 , BTECH , BTECH , No Degree , No Degree , No Profile',
#  'project manager , work from home , performing , mar , public , android studio , project , store , google , application , kotlin , resume , github , weather , java , computer science , completion , assessment , python , organization , campus , technology , 0 , BTECH , BS , No Degree , No Degree , No Profile',
#  'pizza delivery , work from home , api , training , natural language , general , showcase , algorithms , internships , css , deep learning , mysql , design , learning techniques , keras , apache , heroku , particular , speech recognition , models , email , project , mask , aws , exploratory data analysis , mongodb , processing , fit , computer vision , resume , internet of things , java , machine learning , computer science , opencv , framework , django , cassandra , assessment , scikit-learn , app , python , pizza , unsupervised learning , web , artificial intelligence , html , online , 0 , BTECH , BS , MS , No Degree , No Profile',
#  'work from home
#  'work from home , e-commerce , tableau , mumbai , assessment , computer technology , php , python , algorithms , resume , javascript , application , cpp , android , css , ngo , sql , studio , html , 0 , BS , MS , No Degree , No Profile',
#  'devops , student , web apps , core java , computing , mean stack , devops , algorithms , jenkins , credit , kubernetes , css , vendors , protocol , information technology , mysql , session management , scratch , angular , docker , hindi , linux , cluster , swimming , windows , programming concepts , digital , english , advanced , lal , data security , bootstrap , shipping , spring boot , email , project , store , application , default , thymeleaf , cost effective , github , debit cards , rest , data operations , building , computer science , auditing , dynamic data , languages , html5 , hibernate , operating systems , tennis , data integrity , management system , dac , jira , volleyball , hobbies , cart , learning , cloud storage , database , online , 0 , BS , MS , No Degree , No Profile',
#  'work from home , system administrator , full time , student , socket.io , web development , robotics , algorithms , computer networking , adobe photoshop , mysql , angular , statistical modeling , node.js , jis , google , wordpress , application , c programming , mongodb , resume , hiring , machine learning , computer science , chat , django , it infrastructure , completion , assessment , python , javascript , digital marketing , mathematics , html , database , online , 0 , BTECH , BS , MS , No Degree , No Profile',
#  'work from home , technical consultant , white hat hacker , training , internships , css , forest , information technology , pen , data analytics , shape , real estate , linear regression , models , google , c programming , introduction to , passenger , resume , decision trees , ibm , prediction , elements , paper , java , logistic regression , machine learning , fundamentals , technology risk , arduino , research , completion , assessment , data science , python , white hat , digital marketing , metrics , working experience , html , online , 4 , BTECH , BS , No Degree , No Degree , No Profile',
#  'back end developer , application developer , checker , training , retail , pair programming , ruby on rails , private banking , jenkins , scrum , developers , golang , mysql , databases , sublime text , ltd , energy , enterprise , spring boot , agile , project , application , kotlin , microservices , sprint planning , requirements gathering , programming languages , testing , gitlab , features , flow , junit , computer science , export , optimization algorithms , client requirements , scala , management system , one , javascript , price optimization , technology , 1 , No Degree , MS , No Degree , No Profile',
#  'back end developer , application developer , management consulting , retail , pair programming , ruby on rails , scrum , golang , mysql , databases , sublime text , ltd , energy , enterprise , agile , application , kotlin , programming languages , testing , management consulting , features , junit , computer science , export , optimization algorithms , client requirements , scala , javascript , price optimization , technology , data engineering , 0 , No Degree , MS , No Degree , No Profile',
#  'science intern , work from home , performance analysis , design web , showcase , internships , css , adobe photoshop , demand , mar , mysql , authentication , hindi , interior design , postgresql , models , application , adobe illustrator , prediction , resume , java , machine learning , electricity , forming , foundation , completion , assessment , data science , python , forecasting , technology , artificial intelligence , cd , html , 0 , BS , MS , MSC , MS , No Degree , No Profile',
#  'science intern , work from home , big data analytics , algorithms , internships , deep learning , rapid growth , platforms , interpersonal skills , statistical modeling , natural language processing , sql , resume , neural networks , fostering , running , machine learning , computer science , assessment , data science , python , ion , technology , 5 , BTECH , MS , No Degree , No Profile',
#  'science intern , work from home , encryption , general , internships , spark , deep learning , data transfer , mar , data analytics , models , sql , project , coursera , devices , fit , mumbai , resume , time series analysis , java , machine learning , building , statistics , big data , assessment , data science , python , face recognition , one , organization , wireless , technology , stock exchange , online , 0 , BE , No Degree , No Degree , No Profile',
#  'work from home , completion , fit , assessment , resume , ux design , android , apps , kotlin , 0 , BE , BTECH , MS , No Degree , No Profile',
#  'work from home , classifier , partner , matplotlib , customer , internships , spark , validation , classification , deep learning , telecom , case , information technology , data analytics , model building , eda , screening , roc , architecture , sql , business analytics , pandas , prediction , resume , conversion rate , features , machine learning , opencv , statistics , foundation , tableau , assessment , data science , python , ml , organization , lcr , civil engineering , online , 0 , BE , No Degree , No Degree , No Profile',
#  'work from home , learning analyst , classifier , lead developer , partner , student , personal assistant , technical lead , autocad , training , exhibition , algorithms , classification , deep learning , learning techniques , docker , hypothesis testing , gan , intelligence , computer vision , logistic regression , features , raw materials , django , foundation , data science , object detection , sellers , internships , forest , mar , hindi , english , twitter , project , autocad , video , mongodb , angularjs , matlab , java , srm , machine learning , soft skills , computer science , forming , research , flask , completion , 365 , one , technology , vm , social awareness , physics , sqlite , vs , mysql , data analytics , gnu octave , natural language processing , jquery , advanced , bootstrap , linear regression , email , coursera , microsoft , edge , economics , nvidia , assessment , web , database , online , image processing , 10k , css , azure , teams , excel , tracker , application , c programming , resume , paper , neural networks , led , auditing , returns , python , swot analysis , 4 , BTECH , BS , MS , No Degree , No Profile',
#  'work from home , computer technology , optimization , watson , css , deep learning , mar , data analytics , public , keras , natural language processing , linear regression , models , sql , teamwork , text classification , coursera , introduction to , computer vision , microsoft , resume , prediction , datasets , neural networks , credit cards , ibm , machine learning , fundamentals , computer science , django , sentiment analysis , dashboard , completion , assessment , tuning , python , organization , artificial intelligence , fraud detection , html , online , 0 , BE , BS , No Degree , No Degree , No Profile',
#  'work from home , student , training , internships , healthcare , sqlite , mysql , design , cancer , firebase , pdf , diagnose , status , android studio , project , kotlin , introduction to , prediction , resume , zoom , java , machine learning , computer science , android development , notes , completion , assessment , app , python , one , ml , lung , technology , sdk , coaching , database , online , 2 , BTECH , BS , No Degree , No Degree , No Profile',
#  'work from home , full time , air , manual testing , firebase , assessment , fire safety , training , completion , secondary education , resume , safety engineering , android , aviation , mobile , web applications , software testing , computer science , health , 0 , BS , No Degree , No Degree , No Profile',
#  'cloud architect , lead consultant , certified scrum master , traffic manager , devops , data engineer , zookeeper , solution architect , application developer , computing , multi-tenant , security , microsoft azure , platforms , angular , web api , docker , databases , gateway , rabbitmq , printing , messaging , atlassian , building , ec2 , html5 , scala , workflow , abstracts , notification , pipeline , server side , devops , powershell , kubernetes , general electric , protocol , akka , speech , cluster , ltd , wpf , agile , groups , mongodb , microservices , microsoft word , programming languages , range , redis , architecting , rest , java , disaster recovery , machine learning , git , mqtt , boarding , extreme programming , amqp , client side , data engineering , working experience , scrum , healthcare , message queue , distributed caching , information technology , design , hub , advanced , instrumental , apache kafka , architecture , google , manufacturing , aws , oracle coherence , bus , internet of things , eai , big data , cassandra , jira , cloud services , high availability , css , nosql , b2c , analytics , authentication , cleansing , authorization , teams , enterprise , c# , models , application , lake , devices , stream processing , transformation , storage , framework , coverity , cosmos , bamboo , hbase , python , orchestration , 14 , BE , BS , MS , No Degree , No Profile',
solutions , javascript , technology , insurance , scrum , developers , vendors , affirmative action , collaboration , launches , cash flow , metallurgy , timelines , architecture , omni , email , work effectively , aws , project delivery , saas , program management professional , statutory compliances , amazon , pmp , financial analysis , online , csat , redux , ug , vip , analytics , pos , revenue , authorization , internet , risk , teams , go , enterprise , productivity , models , transparency , b2b , dmaic , pnl , transformations , led , kaizen , drive , e-commerce , metrics , presentations , 9 , BE , BTECH , BS , MS , No Degree , No Profile',
#  'full stack developer , software engineer , full time , software developer , api , express.js , redux , css , product requirements , designation , ug , affirmative action , authentication , databases , hindi , maintenance , yarn , authorization , english , node.js , bootstrap , jasmine , status , postgresql , specifications , agile , email , project , mocha , application , mongodb , numbers , vast , hooks , npm , mumbai , github , components , features , c++ , languages , fork , html5 , dashboard , sass , python , form , javascript , jira , web , technology , cash , program management , 0 , No Degree , MS , No Degree , No Profile',
#  'owner , software developer , team leader , full time , systems engineer , api , web development , web apps , general , blogging , telugu , image processing , css , microsoft azure , security , designation , deep learning , blogs , architectural patterns , data transfer , nlp , sqlite , affirmative action , mysql , hindi , docker , keras , maintenance , pos , instagram , php , jquery , digital , english , mobile phone , artificial neural networks , json , speech recognition , authorization , web applications , enterprise , status , bootstrap , c# , agile , spring boot , email , project , store , google , aws , tesseract , live , photos , xamarin , computer vision , forms , prediction , paper , surveillance , rest , led , c++ , nltk , machine learning , opencv , django , languages , framework , heart disease , html5 , mobile applications , flask , urdu , pil , python , javascript , technology , database , ajax , 0 , BE , BTECH , BS , MS , No Degree , No Profile',
#  'software engineer , quality assurance , software developer , full time , informatica , automation , retail , parcel , transport systems , streamlining , telugu , project managers , carriers , data migration , vendors , affirmative action , health , samsung , hindi , cloud , etl , vendor management , data collection , azure , accessories , maintenance , toshiba , consumer privacy , authorization , english , shopping , teams , status , postgresql , email , fedex , store , transportation , operations , facebook , art , data analysis , privacy act , flow , online , microsoft access , resolve , languages , payments , supply chain , teradata , kannada , merchandising , textiles , data integration , it , javascript , history , organization , technology , data engineering , talend , database , feeds , 2 , BE , BTECH , BS , MS , No Degree , No Profile',
#  'software engineer , data analyst , full time , data scientist , front end developer , matplotlib , reinforcement , telugu , algorithms , visual studio code , css , access , classification , deep learning , anomaly detection , mar , affirmative action , mcs , mysql , user experience , hindi , keras , ltd , kpi , json , ios , english , authorization , pmd , status , productivity , email , business analytics , pandas , business intelligence , application , numpy , angularjs , emulator , microsoft , electronics , neural networks , datasets , persona , android , nltk , machine learning , react native , opencv , django , framework , languages , scikit-learn , data science , python , mobile , form , javascript , predictive analytics , web , notification , artificial intelligence , availability , base , html , 0 , BE , BTECH , MS , No Degree , No Profile',
#  'business operations analyst , research intern , business development , full time , contractual , turn , general , cafe , sales performance , designation , rtv , ug , vendors , mar , affirmative action , collaboration , hindi , gap analysis , vendor management , maintenance , revenue , ltd , kpi , authorization , english , teams , energy , escalation , status , excel , customer service , email , business analysis , project , service quality , sql , business analytics , kra , bpo , less , industrial products , business operations , range , operations management , serviceability , machinery , electronics , training & development , product strategy , power trading , testing process , drive , resolve , customer experience , finance , hiring , quality improvement , payments , research , supply chain , procurement , languages , process management , tableau , fleet , analytical support , management system , one , scheduling , javascript , workflow , dce , optimization strategies , metrics , pricing optimization , 1 , BE , BTECH , MS , No Degree , No Profile',
#  'project lead , full time , general , ug , mar , affirmative action , design , technical architecture , collaboration , maintenance , firebase , ltd , authorization , node.js , status , grails , postgresql , email , project , gitlab , react native , building , mobile applications , javascript , web , 0 , BE , BTECH , No Degree , No Degree , No Profile',
#  'application support , software engineer , management trainee , devops , software developer , full time , gfs , training , testing tools , conducting , scanning , core banking , test cases , digital , status , specifications , chat , project work , octopus , data science , french , automation , outlook , spring integration , devops , interfaces , designation , hindi , english , screens , swap , live , mongodb , angularjs , rest , c++ , machine learning , documentation , sonarqube , javascript , technology , external clients , sales & distribution , performing , fusion , affirmative action , mysql , data analytics , real estate , maintenance , dynamo , prevention , email , google , aws , prediction , credit cards , junit , customer experience , languages , software requirements , text analytics , apps , international exposure , database , online , api , jenkins , migrating , revenue , authorization , rtc , plugin , models , application , less , adherence , electronics , servers , framework , preparation , python , reviews , cloud computing , 0 , BE , BTECH , MSC , MS , MS , No Degree , No Profile',
#  'teaching assistant , senior software engineer , full time , software developer , ecommerce , web development , core java , general , algorithms , jenkins , visual studio code , designation , ug , mar , affirmative action , information technology , mysql , hindi , maintenance , ltd , windows , vim , authorization , internet , english , node.js , status , opengl , email , express , pandas , application , mongodb , introduction to , numpy , ubuntu , bitbucket , redis , github , mac os , c++ , kibana , languages , scikit-learn , python , javascript , jira , database , teaching , 0 , BE , BTECH , MS , MTECH , No Degree , No Profile',
#  'application support , quality assurance , software developer , programmer analyst , full time , retail , web development , redux , css , designation , sqlite , affirmative action , hindi , maintenance , firebase , json , authorization , english , node.js , intelligence , status , email , project , express , google , application , mongodb , xml , mainframe , android , c++ , running , debugging , git , computer science , languages , dashboard , javascript , html , 0 , BE , BTECH , BS , No Degree , No Degree , No Profile',
#  'automation test engineer , software test engineer , full time , testing engineer , automation , reporting , manual testing , telugu , x-ray , performing , css , change requests , designation , regression testing , e2e , functional testing , tamil , validity , affirmative action , testng , jmeter , test scripts , mysql , gui testing , product concept , beginner , maintenance , ltd , typescript , test cases , working experience , json , authorization , english , test execution , status , advanced product quality planning (apqp) , software testing , automotive , email , project , database testing , integration testing , windows 10 , less , selenium webdriver , smoke testing , scenario , html , cucumber , user stories , github , writing , retesting , languages , framework , preparation , system testing , kannada , sql server , data integrity , javascript , jira , eclipse , agile testing , product life cycle , sanity testing , publishing , 0 , BS , MS , No Degree , No Profile',
#  'full time , presentations , group discussions , general , interviewing , team management , designation , background checks , ug , creative services , portals , affirmative action , conducting , health , information technology , hindi , angular , offers , physicals , sourcing , authorization , english , screening , status , directors , social media , mascot , email , hunting , linkedin , less , android , pipelines , employee relations , hiring , recruiting , finance , languages , resource management , it recruitment , communications , javascript , writers , expenses , campus , distributors , digital marketing , hr operations , learning , vendor contracts , 4 , BE , BTECH , No Degree , No Degree , No Profile',
#  'full time , front end web developer , front end developer , software developer , api , web development , css , designation , ug , pages , visual studio , vs , affirmative action , mysql , maintenance , jquery , json , authorization , english , node.js , status , software testing , email , project , application , chrome , less , mumbai , git , building , languages , html5 , dashboard , software design , python , javascript , ajax , 0 , BE , BTECH , No Degree , No Degree , No Profile',
#  'cyber security , automation engineer , full time , software developer , cyber security , automation , functionality , web development , fuel , core java , redux , general , visual studio code , dimension , css , research development , designation , ug , scripting , affirmative action , assembly , games , mysql , oracle , angular , hindi , maintenance , php , sts , authorization , english , sharepoint , graphs , onedrive , bootstrap , status , servlets , excel , spring boot , 12c , cad , email , project , postgresql , application , mongodb , leadership , microsoft , features , c++ , languages , pycharm , gear , html5 , dashboard , security awareness , java api , jira , engineers , eclipse , drawing , javascript , efficacy , creo , 0 , BE , BTECH , MS , No Degree , No Profile',
#  ...]

# %%
cos_sim_list = get_tf_idf_cosine_similarity(job_description,all_resume_text)
# Out:
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# C:\Users\maduu\anaconda3\lib\site-packages\sklearn\utils\validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(

# %%
zipped_resume_rating = zip(cos_sim_list,df_cp.name,[x for x in range(len(df))])
sorted_resume_rating_list = sorted(zipped_resume_rating, key = lambda x: x[0], reverse=True)

# %% [markdown]
# # Generating the DataFrame which contains the name of the candidate with his/her cosine score(%)

# %%
resume_score = [round(x*100,2) for x in cos_sim_list]

# %%
resume_score
# Out:
# [25.42,
#  32.91,
#  29.66,
#  38.7,
#  35.09,
#  19.89,
#  33.38,
#  34.28,
#  29.77,
#  31.28,
#  27.75,
#  23.46,
#  24.88,
#  35.36,
#  29.77,
#  29.77,
#  36.78,
#  32.1,
#  32.17,
#  29.05,
#  37.22,
#  33.15,
#  11.48,
#  20.3,
#  21.4,
#  33.49,
#  32.48,
#  29.67,
#  32.48,
#  24.88,
#  39.99,
#  31.71,
#  37.21,
#  31.13,
#  23.2,
#  31.71,
#  27.74,
#  36.11,
#  28.13,
#  32.74,
#  18.04,
#  34.25,
#  32.82,
#  32.82,
#  44.02,
#  35.71,
#  24.31,
#  29.67,
#  35.94,
#  20.58,
#  33.38,
#  14.36,
#  35.1,
#  34.24,
#  36.36,
#  22.97,
#  20.58,
#  27.84,
#  10.89,
#  25.3,
#  35.45,
#  21.88,
#  33.83,
#  33.83,
#  27.84,
#  44.18,
#  35.09,
#  29.77,
#  37.51,
#  35.36,
#  34.0,
#  31.01,
#  32.04,
#  31.67,
#  33.38,
#  47.37,
#  37.69,
#  34.53,
#  32.04,
#  25.71,
#  23.2,
#  32.48,
#  22.97,
#  31.13,
#  38.36,
#  42.68,
#  43.31,
#  29.28,
#  33.03,
#  34.28,
#  38.67,
#  32.68,
#  24.88,
#  41.94,
#  35.16,
#  36.75,
#  32.64,
#  39.37,
#  50.84,
#  37.88,
#  34.38,
#  32.52,
#  30.39,
#  40.19,
#  29.96,
#  31.53,
#  30.03,
#  23.2,
#  29.67,
#  22.01,
#  26.16,
#  21.05,
#  30.69,
#  33.55,
#  38.28,
#  10.83,
#  34.24,
#  26.79,
#  20.3,
#  36.8,
#  25.71,
#  33.15,
#  33.15,
#  33.67,
#  38.92,
#  34.5,
#  40.71,
#  28.71,
#  27.62,
#  29.83,
#  32.82,
#  31.67,
#  41.76,
#  38.75,
#  24.88,
#  28.91,
#  32.68,
#  28.25,
#  42.85,
#  29.96,
#  30.64,
#  15.63,
#  24.36,
#  36.98,
#  30.69,
#  38.67,
#  23.2,
#  38.04,
#  38.31,
#  32.03,
#  26.79,
#  29.38,
#  25.06,
#  32.91,
#  40.6,
#  34.81,
#  11.48,
#  32.85,
#  36.72,
#  26.93,
#  43.0,
#  32.04,
#  24.31,
#  26.57,
#  28.56,
#  37.97,
#  29.96,
#  30.78,
#  31.61,
#  33.53,
#  30.48,
#  37.35,
#  36.27,
#  35.78,
#  34.0,
#  34.53,
#  32.13,
#  41.5,
#  41.5,
#  27.32,
#  36.03,
#  14.53,
#  38.8,
#  19.89,
#  37.89,
#  31.8,
#  31.8,
#  33.89,
#  39.23,
#  33.56,
#  33.56,
#  20.3,
#  29.28,
#  18.95,
#  34.59,
#  41.94,
#  32.73,
#  35.09,
#  24.88,
#  36.72,
#  30.78,
#  32.74,
#  27.62,
#  45.95,
#  33.76,
#  23.2,
#  24.88,
#  29.1,
#  31.53,
#  26.57,
#  38.87,
#  34.72,
#  29.77,
#  36.09,
#  29.67,
#  35.16,
#  30.62,
#  21.88,
#  33.38,
#  29.05,
#  37.51,
#  27.57,
#  27.76,
#  34.81,
#  32.74,
#  36.09,
#  8.18,
#  36.11,
#  14.06,
#  31.85,
#  15.74,
#  10.94,
#  38.75,
#  38.75,
#  38.98,
#  34.45,
#  46.12,
#  26.16,
#  24.88,
#  29.67,
#  7.26,
#  42.8,
#  19.44,
#  37.89,
#  16.95,
#  37.66,
#  39.23,
#  26.16,
#  33.15,
#  20.58,
#  27.74,
#  31.58,
#  37.25,
#  32.64,
#  31.13,
#  32.82,
#  29.38,
#  24.31,
#  28.87,
#  10.94,
#  27.97,
#  33.38,
#  35.1,
#  39.46,
#  34.24,
#  24.21,
#  35.81,
#  24.31,
#  13.53,
#  33.76,
#  36.54,
#  33.81,
#  36.02,
#  29.1,
#  26.57,
#  34.05,
#  24.88,
#  31.13,
#  32.64,
#  32.54,
#  35.78,
#  33.38,
#  14.53,
#  40.19,
#  23.01,
#  42.99,
#  24.36,
#  15.63,
#  33.03,
#  32.48,
#  26.16,
#  37.89,
#  33.28,
#  39.14,
#  30.2,
#  34.25,
#  36.0,
#  31.13,
#  33.56,
#  37.66,
#  23.0,
#  35.09,
#  40.63,
#  34.51,
#  34.78,
#  27.84,
#  39.78,
#  24.21,
#  40.92,
#  33.55,
#  41.05,
#  32.82,
#  21.88,
#  10.94,
#  29.28,
#  20.58,
#  36.09,
#  37.85,
#  34.0,
#  30.62,
#  39.06,
#  30.62,
#  44.13,
#  34.28,
#  39.17,
#  32.82,
#  39.79,
#  27.62,
#  35.73,
#  27.39,
#  32.32,
#  23.53,
#  34.51,
#  34.51,
#  26.79,
#  19.44,
#  33.6,
#  32.82,
#  37.22,
#  30.2,
#  34.45,
#  29.67,
#  34.94,
#  31.3,
#  27.62,
#  31.25,
#  33.78,
#  32.04,
#  33.28,
#  26.79,
#  29.38,
#  37.62,
#  14.06,
#  25.71,
#  34.25,
#  21.88,
#  23.01,
#  19.89,
#  38.33,
#  26.16,
#  29.96,
#  16.95,
#  15.51,
#  24.31,
#  36.31,
#  25.0,
#  20.58,
#  39.78,
#  39.06,
#  29.28,
#  31.13,
#  10.83,
#  35.18,
#  35.18,
#  33.76,
#  27.97,
#  34.51,
#  20.58,
#  24.31,
#  24.36,
#  25.84,
#  25.84,
#  31.67,
#  30.01,
#  10.83,
#  33.46,
#  31.13,
#  40.8,
#  40.51,
#  35.16,
#  21.4,
#  35.19,
#  30.94,
#  32.82,
#  24.88,
#  20.4,
#  39.39,
#  24.88,
#  27.62,
#  35.16,
#  34.45,
#  33.7,
#  32.04,
#  35.16,
#  28.87,
#  25.26,
#  24.88,
#  28.87,
#  31.13,
#  29.83,
#  43.98,
#  24.88,
#  26.16,
#  29.28,
#  29.28,
#  28.56,
#  34.79,
#  26.93,
#  25.68,
#  33.08,
#  24.31,
#  24.88,
#  31.05,
#  31.59,
#  29.96,
#  41.5,
#  34.53,
#  34.53,
#  20.58,
#  38.57,
#  27.97,
#  26.79,
#  32.68,
#  29.1,
#  31.3,
#  36.76,
#  30.62,
#  35.81,
#  27.62,
#  9.57,
#  25.26,
#  36.72,
#  33.38,
#  20.58,
#  23.0,
#  27.84,
#  33.53,
#  42.44,
#  42.44,
#  30.33,
#  43.25,
#  35.51,
#  27.43,
#  8.26,
#  27.62,
#  41.94,
#  39.78,
#  27.62,
#  35.91,
#  32.66,
#  35.81,
#  31.13,
#  32.54,
#  36.76,
#  24.31,
#  31.13,
#  26.79,
#  16.37,
#  33.6,
#  16.27,
#  33.89,
#  33.89,
#  25.86,
#  20.25,
#  18.5,
#  35.6,
#  40.19,
#  33.17,
#  17.97,
#  27.62,
#  23.6,
#  28.91,
#  17.12,
#  27.02,
#  30.45,
#  37.42,
#  18.87,
#  22.51,
#  42.97,
#  21.48,
#  17.39,
#  25.71,
#  18.76,
#  18.83,
#  26.57,
#  21.05,
#  26.39,
#  35.44,
#  18.63,
#  25.14,
#  34.24,
#  25.58,
#  23.6,
#  24.82,
#  16.37,
#  27.97,
#  38.39,
#  26.63,
#  20.54,
#  34.81,
#  28.56,
#  17.23,
#  32.06,
#  35.91,
#  17.97,
#  17.86,
#  25.0,
#  19.35,
#  28.71,
#  21.77,
#  37.23,
#  25.81,
#  22.51,
#  30.03,
#  24.04,
#  39.85,
#  27.07,
#  26.63,
#  42.54,
#  26.79,
#  17.14,
#  18.76,
#  30.75,
#  18.78,
#  36.36,
#  38.2,
#  31.16,
#  24.83,
#  22.25,
#  39.25,
#  28.71,
#  29.1,
#  24.95,
#  25.58,
#  21.48,
#  31.85,
#  29.21,
#  34.26,
#  18.95,
#  20.54,
#  34.77,
#  25.84,
#  39.57,
#  32.73,
#  35.73,
#  22.03,
#  24.77,
#  39.07,
#  23.44,
#  17.19,
#  31.11,
#  32.23,
#  27.07,
#  29.53,
#  33.38,
#  31.22,
#  23.92,
#  36.03,
#  19.85,
#  12.86,
#  38.36,
#  23.6,
#  28.64,
#  18.77,
#  15.91,
#  35.49,
#  26.77,
#  28.88,
#  33.53,
#  42.19,
#  16.75,
#  17.39,
#  15.34,
#  19.52,
#  14.69,
#  23.97,
#  15.74,
#  21.7,
#  19.53,
#  32.85,
#  26.53,
#  22.35,
#  19.14,
#  27.07,
#  17.39,
#  25.04,
#  19.69,
#  19.95,
#  17.23,
#  20.98,
#  18.83,
#  23.92,
#  27.62,
#  12.86,
#  23.53,
#  18.77,
#  24.77,
#  19.57,
#  20.54,
#  17.12,
#  26.57,
#  24.81,
#  16.24,
#  17.52,
#  21.36,
#  19.85,
#  33.7,
#  31.83,
#  23.11,
#  37.26,
#  21.2,
#  20.4,
#  22.51,
#  35.19,
#  38.73,
#  29.21,
#  30.62,
#  13.4,
#  21.18,
#  40.36,
#  21.1,
#  17.47,
#  19.89,
#  46.55,
#  16.52,
#  20.31,
#  25.68,
#  22.85,
#  17.39,
#  28.71,
#  39.57,
#  34.24,
#  22.33,
#  23.11,
#  34.28,
#  16.95,
#  27.26,
#  23.67,
#  37.52,
#  27.39,
#  46.54,
#  27.35,
#  42.54,
#  27.78,
#  39.07,
#  22.52,
#  28.25,
#  23.92,
#  25.71,
#  19.69,
#  20.46,
#  26.57,
#  17.36,
#  30.81,
#  27.97,
#  18.04,
#  28.64,
#  20.75,
#  17.97,
#  23.04,
#  23.09,
#  17.95,
#  39.04,
#  33.38,
#  19.04,
#  24.6,
#  37.66,
#  37.38,
#  31.26,
#  29.77,
#  26.93,
#  23.04,
#  17.14,
#  25.41,
#  24.36,
#  31.26,
#  19.62,
#  18.87,
#  17.39,
#  36.32,
#  31.4,
#  17.59,
#  21.05,
#  31.25,
#  14.86,
#  29.96,
#  17.97,
#  24.36,
#  10.85,
#  24.31,
#  24.82,
#  16.52,
#  35.91,
#  26.91,
#  20.4,
#  16.95,
#  29.67,
#  36.62,
#  21.48,
#  27.62,
#  21.66,
#  16.95,
#  29.67,
#  17.36,
#  18.06,
#  26.11,
#  27.02,
#  24.88,
#  21.01,
#  18.02,
#  21.4,
#  20.46,
#  17.23,
#  17.47,
#  16.95,
#  29.96,
#  25.68,
#  20.4,
#  21.66,
#  41.95,
#  22.52,
#  16.24,
#  17.95,
#  30.43,
#  17.47,
#  14.32,
#  32.54,
#  37.81,
#  33.55,
#  40.07,
#  16.77,
#  19.59,
#  32.48,
#  33.76,
#  34.24,
#  27.95,
#  32.15,
#  22.42,
#  30.48,
#  24.81,
#  38.8,
#  25.06,
#  22.51,
#  20.1,
#  18.17,
#  23.87,
#  23.68,
#  39.9,
#  27.24,
#  15.35,
#  26.53,
#  23.67,
#  32.91,
#  33.38,
#  35.2,
#  28.13,
#  29.66,
#  39.51,
#  14.36,
#  14.32,
#  35.91,
#  19.37,
#  26.52,
#  13.26,
#  40.75,
#  25.78,
#  24.36,
#  38.29,
#  21.02,
#  20.3,
#  14.44,
#  ...]

# %%
# Out:
#                       name  resume_score(%)
# 464       Rucha Patwardhan            59.38
# 1542   Technical Architect            51.72
# 1095  Cloud Infrastructure            51.66
# 98          Microsoft Word            50.84
# 75             Credit Card            47.37
